# %%
import pandas as pd
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
from matplotlib import rc # 한글 그래픽 처리
import seaborn as sns # r에서 ggplot이라 생각하면됨. 쓸때 한글처리 주의.
# %matplotlib inline
rc('font', family='malgun gothic')
rc('axes', unicode_minus=False)

# %%
train = pd.read_csv('./train.csv',engine='python',encoding='cp949')
a = []
for i in range(len(train)):
    a.append(int(train['gdp_for_year'][i].replace(',','')))
train['gdp_for_year'] = a
train.head(3)
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
#
#    suicides_100k_pop country_year  HDI_for_year  gdp_for_year  \
# 0               6.71  Albania1987           NaN    2156624900
# 1               5.19  Albania1987           NaN    2156624900
# 2               4.83  Albania1987           NaN    2156624900
#
#    gdp_per_capital    generation
# 0              796  Generation X
# 1              796        Silent
# 2              796  Generation X

# %%
tmp = pd.read_csv("./test_mini.csv")
a = []
for i in range(len(tmp)):
    a.append(int(tmp['gdp_for_year'][i].replace(',','')))
tmp['gdp_for_year'] = a
tmp.head()
# Out:
#                country  year     sex          age  population  \
# 0  Antigua and Barbuda  2015  female  55-74 years        6403
# 1  Antigua and Barbuda  2015  female  15-24 years        8561
# 2  Antigua and Barbuda  2015  female  25-34 years        7740
# 3  Antigua and Barbuda  2015  female  35-54 years       15323
# 4  Antigua and Barbuda  2015  female   5-14 years        8239
#
#    suicides_100k_pop             country_year  HDI_for_year  gdp_for_year  \
# 0              15.62  Antigua and Barbuda2015           NaN    1364863037
# 1               0.00  Antigua and Barbuda2015           NaN    1364863037
# 2               0.00  Antigua and Barbuda2015           NaN    1364863037
# 3               0.00  Antigua and Barbuda2015           NaN    1364863037
# 4               0.00  Antigua and Barbuda2015           NaN    1364863037
#
#    gdp_per_capital    generation
# 0            14853       Boomers
# 1            14853    Millenials
# 2            14853    Millenials
# 3            14853  Generation X
# 4            14853  Generation Z

# %%
gold = pd.read_csv('./국제금값종장기준(일간).csv',encoding='cp949',engine='python')
oilUSA = pd.read_csv('./텍사스산기름값데이터.csv',encoding='cp949',engine='python')
product = pd.read_csv('./모든상품의글로벌가격지수.csv',encoding='cp949',engine='python')
oilEU = pd.read_csv('./유럽산기름값연간데이터.csv',encoding='cp949',engine='python')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-dea8221c96e5> in <module>
# ----> 1 gold = pd.read_csv('./국제금값종장기준(일간).csv',encoding='cp949',engine='python')
#       2 oilUSA = pd.read_csv('./텍사스산기름값데이터.csv',encoding='cp949',engine='python')
#       3 product = pd.read_csv('./모든상품의글로벌가격지수.csv',encoding='cp949',engine='python')
#       4 oilEU = pd.read_csv('./유럽산기름값연간데이터.csv',encoding='cp949',engine='python')
#
# /anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# /anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# /anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1130                                  ' "c", "python", or' ' "python-fwf")'.format(
#    1131                                      engine=engine))
# -> 1132             self._engine = klass(self.f, **self.options)
#    1133
#    1134     def _failover_to_python(self):
#
# /anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, **kwds)
#    2223         f, handles = _get_handle(f, mode, encoding=self.encoding,
#    2224                                  compression=self.compression,
# -> 2225                                  memory_map=self.memory_map)
#    2226         self.handles.extend(handles)
#    2227
#
# /anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     422         elif encoding:
#     423             # Python 3 and encoding
# --> 424             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     425         elif is_text:
#     426             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: './국제금값종장기준(일간).csv'

# %%
gold.head(3), oilUSA.head(3), product.head(3), oilEU.head(3)

# %%
gold.DATE = pd.to_datetime(gold.DATE,format = '%Y-%m-%d')
gold['DATE'] = gold.DATE.dt.year
gold_data = gold.groupby('DATE')['PRICE'].agg([('goldmin',min),('goldmax',max),('goldmean','mean')]).reset_index()
gold_data['minmaxprice'] = abs(gold_data.goldmax - gold_data.goldmin)
gold_data.head(2)

# %%
oilUSA.DATE = pd.to_datetime(oilUSA.DATE,format = '%Y-%m-%d')
oilUSA['DATE'] = oilUSA.DATE.dt.year
product.DATE = pd.to_datetime(product.DATE,format = '%Y-%m-%d')
product['DATE'] = product.DATE.dt.year
oilEU.DATE = pd.to_datetime(oilEU.DATE,format = '%Y-%m-%d')
oilEU['DATE'] = oilEU.DATE.dt.year

print(oilUSA.head(2))
print(product.head(2))
print(oilEU.head(2))

# %%
addDATA = pd.merge(product,pd.merge(oilEU,pd.merge(gold_data,oilUSA,on='DATE'),on='DATE'),on='DATE')
addDATA = addDATA.rename(columns={'DATE':'year'})
addDATA.head(2)

# %%
country = tmp.country.unique()

addtrain = pd.merge(train,addDATA,on='year')
addtrain = addtrain.query("country in @country")
addtrain.head(3)

# %%
addtest = pd.merge(tmp,addDATA,on='year')
print(addtest.head(3))
print(addtest.tail(3))

# %%
unemploy_m = pd.read_table('./Unemployment_male (%).csv', encoding='euc-kr')
cols = list(range(1, 27))
unemploy_m.drop(unemploy_m.columns[cols], axis=1, inplace=True)
unemploy_m.drop(['2016', '2017', '2018'], axis=1, inplace=True)

unemploy_m_melt = pd.melt(unemploy_m.iloc[:,1:])
unemploy_m_melt.columns = ['year', 'unemployment rate']
unemploy_m_CountryName = list(unemploy_m['Country Name'])*31
unemploy_m_CountryName = pd.DataFrame({'Country Name' : unemploy_m_CountryName})
unemploy_m = pd.concat([unemploy_m_CountryName, unemploy_m_melt], axis=1)
unemploy_m['sex']='male'
unemploy_m = unemploy_m.iloc[:,[0, 1, 3, 2]]
unemploy_m.head(2)

# %%
unemploy_f = pd.read_table('./Unemployment_female (%).csv', encoding='euc-kr')
cols = list(range(1, 26))
unemploy_f.drop(unemploy_f.columns[cols], axis=1, inplace=True)
unemploy_f.drop(['2016', '2017', '2018'], axis=1, inplace=True)

unemploy_f_melt = pd.melt(unemploy_f.iloc[:,1:])
unemploy_f_melt.columns = ['year', 'unemployment rate']
unemploy_f_CountryName = list(unemploy_f['Country Name'])*31
unemploy_f_CountryName = pd.DataFrame({'Country Name' : unemploy_f_CountryName})
unemploy_f = pd.concat([unemploy_f_CountryName, unemploy_f_melt], axis=1)
unemploy_f['sex']='female'
unemploy_f = unemploy_f.iloc[:,[0, 1, 3, 2]]
unemploy_f.head(2)

# %%
unemploy = pd.concat([unemploy_f, unemploy_m])
unemploy = unemploy.sort_values(by=['Country Name', 'year'], ascending=True)
unemploy.head(3)

# %%
unemploy = unemploy[(unemploy.year!='1985') & (unemploy.year!='1986') & (unemploy.year!='1987') & (unemploy.year!='1988') & 
                    (unemploy.year!='1989') & (unemploy.year!='1990')]
unemploy.head()
## 이것을 하는 이유는 unemploy데이터 내 1985년~1990년은 실업률 데이터가 전부 NaN이기 때문!!

# %%
unemploy['Country Name'].replace(to_replace=['Korea, Rep.'], value='Republic of Korea', inplace=True)
unemploy['Country Name'].replace(to_replace=['Slovak Republic'], value='Slovakia', inplace=True)
unemploy['Country Name'].replace(to_replace=['Kyrgyz Republic'], value='Kyrgyzstan', inplace=True)
unemploy['Country Name'].replace(to_replace=['Macao SAR, China'], value='Macau', inplace=True)
unemploy['Country Name'].replace(to_replace=['Bahamas, The'], value='Bahamas', inplace=True)
unemploy['Country Name'].replace(to_replace=['St. Kitts and Nevis'], value='Saint Kitts and Nevis', inplace=True)
unemploy['Country Name'].replace(to_replace=['St. Lucia'], value='Saint Lucia', inplace=True)
unemploy['Country Name'].replace(to_replace=['St. Vincent and the Grenadines'], value='Saint Vincent and Grenadines', inplace=True)

# %%
unemploy['year'] = list(map(int, unemploy['year']))
unemploy.info()

# %%
addtrain.head(2)

# %%
addtrain = pd.merge(addtrain, unemploy, left_on=['country', 'year', 'sex'], 
                   right_on=['Country Name', 'year', 'sex'], 
                   how='left').drop(['Country Name'], axis=1)
addtest = pd.merge(addtest, unemploy, left_on=['country', 'year', 'sex'], 
                   right_on=['Country Name', 'year', 'sex'], 
                   how='left').drop(['Country Name'], axis=1)

# %%
prevalence_depress = pd.read_csv('./share-with-depression-by-gdp-pc.csv')
prevalence_depress = prevalence_depress.iloc[:,:4]
prevalence_depress.drop('Code', axis=1, inplace=True)
prevalence_depress.columns=['country', 'year', 'prevalence of depressive disorders (%)']
prevalence_depress.head(3)

prevalence_depress['country'].replace(to_replace=['Cape Verde'], value='Cabo Verde', inplace=True)
prevalence_depress['country'].replace(to_replace=['Macao'], value='Macau', inplace=True)
prevalence_depress['country'].replace(to_replace=['South Korea'], value='Republic of Korea', inplace=True)
prevalence_depress['country'].replace(to_replace=['Russia'], value='Russian Federation', inplace=True)
prevalence_depress['country'].replace(to_replace=['Saint Vincent and the Grenadines'], 
                                      value='Saint Vincent and Grenadines', inplace=True)

# %%
addtrain = pd.merge(addtrain, prevalence_depress, on=['country', 'year'], how='left')
addtest = pd.merge(addtest, prevalence_depress, on=['country', 'year'], how='left')

# %%
addtest.head(3)

# %%
addtest.drop('HDI_for_year', axis=1, inplace=True)
addtrain.drop('HDI_for_year', axis=1, inplace=True)

addtest.info()

# %%
addtrain.info()

# %%
groupdata = addtrain.groupby(['country','year', 'sex']).agg({'suicides_no':'sum','population':'sum','gdp_for_year':'mean',
                                                             'gdp_per_capital':'mean','productprice':'mean','Euprice':'mean',
                                                             'goldmin':'mean','goldmax':'mean','goldmean':'mean','minmaxprice':'mean',
                                                             'TEXASprice':'mean', 'unemployment rate':'mean', 
                                                             'prevalence of depressive disorders (%)':'mean'}).reset_index()
grouptest = addtest.groupby(['country','year', 'sex']).agg({'population':'sum','gdp_for_year':'mean',
                                                            'gdp_per_capital':'mean','productprice':'mean','Euprice':'mean',
                                                            'goldmin':'mean','goldmax':'mean','goldmean':'mean','minmaxprice':'mean',
                                                            'TEXASprice':'mean', 'unemployment rate':'mean', 
                                                            'prevalence of depressive disorders (%)':'mean'}).reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2ded2b73f34a> in <module>
# ----> 1 groupdata = addtrain.groupby(['country','year', 'sex']).agg({'suicides_no':'sum','population':'sum','gdp_for_year':'mean',
#       2                                                              'gdp_per_capital':'mean','productprice':'mean','Euprice':'mean',
#       3                                                              'goldmin':'mean','goldmax':'mean','goldmean':'mean','minmaxprice':'mean',
#       4                                                              'TEXASprice':'mean', 'unemployment rate':'mean',
#       5                                                              'prevalence of depressive disorders (%)':'mean'}).reset_index()
#
# NameError: name 'addtrain' is not defined

# %%
groupdata['1인당GDP'] = groupdata['gdp_for_year']/groupdata['population']*100
groupdata['oilprice'] = groupdata['Euprice']/groupdata['TEXASprice']*100
groupdata['gdp_product'] = groupdata['gdp_for_year']/groupdata['productprice']*100
groupdata['gdp_gold'] = groupdata['gdp_for_year']/groupdata['goldmean']*100
grouptest['1인당GDP'] = grouptest['gdp_for_year']/grouptest['population']*100
grouptest['oilprice'] = grouptest['Euprice']/grouptest['TEXASprice']*100
grouptest['gdp_product'] = grouptest['gdp_for_year']/grouptest['productprice']*100
grouptest['gdp_gold'] = grouptest['gdp_for_year']/grouptest['goldmean']*100

# %%
abs(groupdata.corr()['suicides_no']).sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-5d3f095fe85e> in <module>
# ----> 1 abs(groupdata.corr()['suicides_no']).sort_values(ascending=False)
#
# NameError: name 'groupdata' is not defined

# %%
### sex : female은 0으로, male은 1로 인코딩하기
groupdata['sex'] = groupdata['sex'].map({'female':0, 'male':1})
grouptest['sex'] = grouptest['sex'].map({'female':0, 'male':1})

print(groupdata.head(2))
print(grouptest.head(2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f84d26d168b9> in <module>
#       1 ### sex : female은 0으로, male은 1로 인코딩하기
# ----> 2 groupdata['sex'] = groupdata['sex'].map({'female':0, 'male':1})
#       3 grouptest['sex'] = grouptest['sex'].map({'female':0, 'male':1})
#       4
#       5 print(groupdata.head(2))
#
# NameError: name 'groupdata' is not defined

# %%
groupdata.info(), grouptest.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3c5de6832190> in <module>
# ----> 1 groupdata.info(), grouptest.info()
#
# NameError: name 'groupdata' is not defined

# %%
groupdata['unemployment rate'] = groupdata['unemployment rate'].fillna(np.mean(groupdata['unemployment rate']))
groupdata['prevalence of depressive disorders (%)'] = groupdata['prevalence of depressive disorders (%)'].fillna(np.mean(groupdata['prevalence of depressive disorders (%)']))

# %%
grouptest['unemployment rate'] = grouptest['unemployment rate'].fillna(np.mean(grouptest['unemployment rate']))
grouptest['prevalence of depressive disorders (%)'] = grouptest['prevalence of depressive disorders (%)'].fillna(np.mean(grouptest['prevalence of depressive disorders (%)']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a14b20687462> in <module>
# ----> 1 grouptest['unemployment rate'] = grouptest['unemployment rate'].fillna(np.mean(grouptest['unemployment rate']))
#       2 grouptest['prevalence of depressive disorders (%)'] = grouptest['prevalence of depressive disorders (%)'].fillna(np.mean(grouptest['prevalence of depressive disorders (%)']))
#
# NameError: name 'grouptest' is not defined

# %%
groupdata.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-64fa96574580> in <module>
# ----> 1 groupdata.head(10)
#
# NameError: name 'groupdata' is not defined

# %%
len(groupdata.columns)

# %%
grouptest.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0e66aea428d1> in <module>
# ----> 1 grouptest.head(10)
#
# NameError: name 'grouptest' is not defined

# %% [markdown]
# ### RandomForestRegressor를 썼을 때(국가와 성별을 기준으로 예측함) → RMSE=760

# %%
###### 국가별 성별로 
country = tmp.country.unique()

from sklearn.ensemble import RandomForestRegressor

nation = []
predict = []

for i in country:
    lastdata = groupdata.query("country == @i").drop(['country'],axis=1)
    testdata = grouptest.query("country == @i").drop(['country'],axis=1)
    X = lastdata.drop('suicides_no',axis=1)
    y = lastdata['suicides_no']
    #X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 0)
    #model = RandomForestRegressor(n_estimators=100).fit(X_train, y_train)
    # model = RandomForestRegressor(random_state=42, n_estimators=100).fit(X, y)
    model = RandomForestRegressor(random_state=42, n_estimators=100).fit(X, y)
    #modelaccuracy.append(model.score(X_test, y_test))
    predict.append(model.predict(testdata)[0])
    predict.append(model.predict(testdata)[1])
    nation.append(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-94f1b50f9fea> in <module>
#       8
#       9 for i in country:
# ---> 10     lastdata = groupdata.query("country == @i").drop(['country'],axis=1)
#      11     testdata = grouptest.query("country == @i").drop(['country'],axis=1)
#      12     X = lastdata.drop('suicides_no',axis=1)
#
# NameError: name 'groupdata' is not defined

# %%
len(nation), len(predict)

# %%
nation1=[]
for i in nation:
    nation1 +=[i for n in range(2)]
nation1[:11]
print(len(nation1))
# Out:
# 0

# %%
pre = pd.DataFrame({'country':nation1,'predict':predict, 'sex':[0, 1]*62})#,'accuracy':modelaccuracy})
#DATA = pre.groupby('country')['predict'].sum().reset_index()
result = pd.read_csv("who_suicide_statistics.csv")
result.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-c366dd985203> in <module>
# ----> 1 pre = pd.DataFrame({'country':nation1,'predict':predict, 'sex':[0, 1]*62})#,'accuracy':modelaccuracy})
#       2 #DATA = pre.groupby('country')['predict'].sum().reset_index()
#       3 result = pd.read_csv("who_suicide_statistics.csv")
#       4 result.head()
#
# /anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# /anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# /anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# /anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     315             lengths = list(set(raw_lengths))
#     316             if len(lengths) > 1:
# --> 317                 raise ValueError('arrays must all be same length')
#     318
#     319             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
result['sex']=result['sex'].map({'female':0, 'male':1})
result.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-8be7ba2d4f9a> in <module>
# ----> 1 result['sex']=result['sex'].map({'female':0, 'male':1})
#       2 result.head()
#
# NameError: name 'result' is not defined

# %%
compare = result.query('year == 2015').groupby(['country', 'sex']).agg({'suicides_no':'sum'}).reset_index()
fin = pd.merge(pre, compare, on=['country', 'sex'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-b64ef9f1456b> in <module>
# ----> 1 compare = result.query('year == 2015').groupby(['country', 'sex']).agg({'suicides_no':'sum'}).reset_index()
#       2 fin = pd.merge(pre, compare, on=['country', 'sex'])
#
# NameError: name 'result' is not defined

# %%
y_true = fin.suicides_no
y_pred = fin.predict
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_true, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-65b856bbae16> in <module>
# ----> 1 y_true = fin.suicides_no
#       2 y_pred = fin.predict
#       3 from sklearn.metrics import mean_squared_error
#       4 np.sqrt(mean_squared_error(y_true, y_pred))
#
# NameError: name 'fin' is not defined

# %%
predict_df = pd.DataFrame({'country':fin.country, 'sex':[0,1]*61, 
                          'true':fin.suicides_no, 'pred':fin.predict})
predict_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-491712690f92> in <module>
# ----> 1 predict_df = pd.DataFrame({'country':fin.country, 'sex':[0,1]*61,
#       2                           'true':fin.suicides_no, 'pred':fin.predict})
#       3 predict_df
#
# NameError: name 'fin' is not defined

# %% [markdown]
# ### Decition Tree를 썼을 때(국가와 성별을 기준으로 예측함) → RMSE = 196.7

# %%
from sklearn.tree import DecisionTreeRegressor

nation2 = []
predict1 = []

for i in country:
    lastdata = groupdata.query("country == @i").drop(['country'],axis=1)
    testdata = grouptest.query("country == @i").drop(['country'],axis=1)
    X = lastdata.drop('suicides_no',axis=1)
    y = lastdata['suicides_no']
    #X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 0)
    #model = RandomForestRegressor(n_estimators=100).fit(X_train, y_train)
    # model = DecisionTreeRegressor(max_depth=8,random_state=42).fit(X, y)
    model = DecisionTreeRegressor(max_depth=8,random_state=42).fit(X, y)
    #modelaccuracy.append(model.score(X_test, y_test))
    predict1.append(model.predict(testdata)[0])
    predict1.append(model.predict(testdata)[1])
    nation2.append(i)
    
print(len(nation2), len(predict1))
# Out:
# 62 124

# %%
nation3=[]
for i in nation2:
    nation3 +=[i for n in range(2)]
nation3[:11]
print(len(nation3))

pre1 = pd.DataFrame({'country':nation3,'predict1':predict1, 'sex':[0, 1]*62})

result1 = pd.read_csv("./who_suicide_statistics.csv")
result1['sex']=result1['sex'].map({'female':0, 'male':1})

compare1 = result1.query('year == 2015').groupby(['country', 'sex']).agg({'suicides_no':'sum'}).reset_index()
fin1 = pd.merge(pre1,compare1,on=['country', 'sex'])
y_true1 = fin1.suicides_no
y_pred1 = fin1.predict1
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_true1, y_pred1))
# Out:
# 124
# 196.70144567792343

# %%
len(fin.suicides_no), len(fin.predict), len(fin1.predict1),
# Out:
# (122, 122, 122)

# %%
predict_df = pd.DataFrame({'country':fin.country, 'sex':[0,1]*61, 
                          'true':fin.suicides_no, 'pred_using_RandomForest':fin.predict, 'pred_using_DecisionTree':fin1.predict1})
predict_df
# Out:
#                           country  sex    true  pred_using_RandomForest  \
# 0             Antigua and Barbuda    0     1.0                     0.15
# 1             Antigua and Barbuda    1     0.0                     0.20
# 2                       Argentina    0   604.0                   640.38
# 3                       Argentina    1  2469.0                  2466.15
# 4                         Armenia    0    19.0                    14.50
# 5                         Armenia    1    55.0                    47.51
# 6                       Australia    0   735.0                   629.38
# 7                       Australia    1  2292.0                  2077.41
# 8                         Austria    0   290.0                   316.36
# 9                         Austria    1   961.0                   992.00
# 10                        Belgium    0   552.0                   555.83
# 11                        Belgium    1  1315.0                  1392.01
# 12                         Belize    0     4.0                     4.17
# 13                         Belize    1    22.0                    12.66
# 14                         Brazil    0  2397.0                  2050.64
# 15                         Brazil    1  8766.0                  7624.08
# 16                          Chile    0   378.0                   326.22
# 17                          Chile    1  1460.0                  1473.59
# 18                       Colombia    0   482.0                   401.27
# 19                       Colombia    1  1850.0                  1709.71
# 20                        Croatia    0   197.0                   196.14
# 21                        Croatia    1   542.0                   567.46
# 22                           Cuba    0   300.0                   331.89
# 23                           Cuba    1  1211.0                  1164.56
# 24                         Cyprus    0     9.0                     8.37
# 25                         Cyprus    1    31.0                    16.05
# 26                 Czech Republic    0   254.0                   262.79
# 27                 Czech Republic    1  1133.0                  1213.19
# 28                        Denmark    0   174.0                   158.55
# 29                        Denmark    1   390.0                   474.06
# ..                            ...  ...     ...                      ...
# 92   Saint Vincent and Grenadines    0     1.0                     0.36
# 93   Saint Vincent and Grenadines    1     2.0                     3.49
# 94                         Serbia    0   269.0                   647.33
# 95                         Serbia    1   793.0                   956.48
# 96                     Seychelles    0     1.0                     1.16
# 97                     Seychelles    1     6.0                     4.24
# 98                      Singapore    0   111.0                   110.91
# 99                      Singapore    1   218.0                   238.82
# 100                      Slovenia    0    90.0                    90.37
# 101                      Slovenia    1   332.0                   354.01
# 102                  South Africa    0   105.0                   120.66
# 103                  South Africa    1   377.0                   403.01
# 104                         Spain    0   923.0                   915.45
# 105                         Spain    1  2681.0                  2668.45
# 106                        Sweden    0   331.0                   358.03
# 107                        Sweden    1   851.0                   817.95
# 108                   Switzerland    0   280.0                   287.22
# 109                   Switzerland    1   793.0                   772.88
# 110                      Thailand    0   839.0                   880.79
# 111                      Thailand    1  3366.0                  3073.90
# 112                        Turkey    0   397.0                   389.51
# 113                        Turkey    1  1135.0                  1096.99
# 114                  Turkmenistan    0    41.0                    40.52
# 115                  Turkmenistan    1    92.0                   110.05
# 116                       Ukraine    0  1426.0                  2704.16
# 117                       Ukraine    1  6148.0                  7408.42
# 118                United Kingdom    0  1178.0                  1003.85
# 119                United Kingdom    1  3732.0                  3369.72
# 120                       Uruguay    0   131.0                   120.38
# 121                       Uruguay    1   499.0                   440.03
#
#      pred_using_DecisionTree
# 0                       0.00
# 1                       0.00
# 2                     687.00
# 3                    2544.00
# 4                      10.00
# 5                      59.00
# 6                     709.00
# 7                    2182.00
# 8                     324.00
# 9                     990.00
# 10                    544.50
# 11                   1459.00
# 12                      5.00
# 13                     18.00
# 14                   2073.00
# 15                   8398.00
# 16                    314.00
# 17                   1510.00
# 18                    371.00
# 19                   1712.75
# 20                    193.00
# 21                    536.00
# 22                    371.00
# 23                   1146.00
# 24                     13.00
# 25                     31.00
# 26                    293.00
# 27                   1196.00
# 28                    160.00
# 29                    477.00
# ..                       ...
# 92                      0.00
# 93                      0.00
# 94                   1051.00
# 95                    997.00
# 96                      2.00
# 97                      2.00
# 98                    106.00
# 99                    250.00
# 100                    63.00
# 101                   415.00
# 102                   121.00
# 103                   459.00
# 104                   960.00
# 105                  2938.00
# 106                   363.00
# 107                   826.25
# 108                   282.00
# 109                   724.00
# 110                   878.00
# 111                  3055.00
# 112                   378.00
# 113                  1148.00
# 114                    28.00
# 115                    92.00
# 116                  1761.00
# 117                  6412.00
# 118                  1071.00
# 119                  3717.00
# 120                   103.00
# 121                   441.00
#
# [122 rows x 5 columns]

# %%
predict_df['sex']=predict_df['sex'].map({0:'female', 1:'male'})
predict_df
# Out:
#                           country     sex    true  pred_using_RandomForest  \
# 0             Antigua and Barbuda  female     1.0                     0.15
# 1             Antigua and Barbuda    male     0.0                     0.20
# 2                       Argentina  female   604.0                   640.38
# 3                       Argentina    male  2469.0                  2466.15
# 4                         Armenia  female    19.0                    14.50
# 5                         Armenia    male    55.0                    47.51
# 6                       Australia  female   735.0                   629.38
# 7                       Australia    male  2292.0                  2077.41
# 8                         Austria  female   290.0                   316.36
# 9                         Austria    male   961.0                   992.00
# 10                        Belgium  female   552.0                   555.83
# 11                        Belgium    male  1315.0                  1392.01
# 12                         Belize  female     4.0                     4.17
# 13                         Belize    male    22.0                    12.66
# 14                         Brazil  female  2397.0                  2050.64
# 15                         Brazil    male  8766.0                  7624.08
# 16                          Chile  female   378.0                   326.22
# 17                          Chile    male  1460.0                  1473.59
# 18                       Colombia  female   482.0                   401.27
# 19                       Colombia    male  1850.0                  1709.71
# 20                        Croatia  female   197.0                   196.14
# 21                        Croatia    male   542.0                   567.46
# 22                           Cuba  female   300.0                   331.89
# 23                           Cuba    male  1211.0                  1164.56
# 24                         Cyprus  female     9.0                     8.37
# 25                         Cyprus    male    31.0                    16.05
# 26                 Czech Republic  female   254.0                   262.79
# 27                 Czech Republic    male  1133.0                  1213.19
# 28                        Denmark  female   174.0                   158.55
# 29                        Denmark    male   390.0                   474.06
# ..                            ...     ...     ...                      ...
# 92   Saint Vincent and Grenadines  female     1.0                     0.36
# 93   Saint Vincent and Grenadines    male     2.0                     3.49
# 94                         Serbia  female   269.0                   647.33
# 95                         Serbia    male   793.0                   956.48
# 96                     Seychelles  female     1.0                     1.16
# 97                     Seychelles    male     6.0                     4.24
# 98                      Singapore  female   111.0                   110.91
# 99                      Singapore    male   218.0                   238.82
# 100                      Slovenia  female    90.0                    90.37
# 101                      Slovenia    male   332.0                   354.01
# 102                  South Africa  female   105.0                   120.66
# 103                  South Africa    male   377.0                   403.01
# 104                         Spain  female   923.0                   915.45
# 105                         Spain    male  2681.0                  2668.45
# 106                        Sweden  female   331.0                   358.03
# 107                        Sweden    male   851.0                   817.95
# 108                   Switzerland  female   280.0                   287.22
# 109                   Switzerland    male   793.0                   772.88
# 110                      Thailand  female   839.0                   880.79
# 111                      Thailand    male  3366.0                  3073.90
# 112                        Turkey  female   397.0                   389.51
# 113                        Turkey    male  1135.0                  1096.99
# 114                  Turkmenistan  female    41.0                    40.52
# 115                  Turkmenistan    male    92.0                   110.05
# 116                       Ukraine  female  1426.0                  2704.16
# 117                       Ukraine    male  6148.0                  7408.42
# 118                United Kingdom  female  1178.0                  1003.85
# 119                United Kingdom    male  3732.0                  3369.72
# 120                       Uruguay  female   131.0                   120.38
# 121                       Uruguay    male   499.0                   440.03
#
#      pred_using_DecisionTree
# 0                       0.00
# 1                       0.00
# 2                     687.00
# 3                    2544.00
# 4                      10.00
# 5                      59.00
# 6                     709.00
# 7                    2182.00
# 8                     324.00
# 9                     990.00
# 10                    544.50
# 11                   1459.00
# 12                      5.00
# 13                     18.00
# 14                   2073.00
# 15                   8398.00
# 16                    314.00
# 17                   1510.00
# 18                    371.00
# 19                   1712.75
# 20                    193.00
# 21                    536.00
# 22                    371.00
# 23                   1146.00
# 24                     13.00
# 25                     31.00
# 26                    293.00
# 27                   1196.00
# 28                    160.00
# 29                    477.00
# ..                       ...
# 92                      0.00
# 93                      0.00
# 94                   1051.00
# 95                    997.00
# 96                      2.00
# 97                      2.00
# 98                    106.00
# 99                    250.00
# 100                    63.00
# 101                   415.00
# 102                   121.00
# 103                   459.00
# 104                   960.00
# 105                  2938.00
# 106                   363.00
# 107                   826.25
# 108                   282.00
# 109                   724.00
# 110                   878.00
# 111                  3055.00
# 112                   378.00
# 113                  1148.00
# 114                    28.00
# 115                    92.00
# 116                  1761.00
# 117                  6412.00
# 118                  1071.00
# 119                  3717.00
# 120                   103.00
# 121                   441.00
#
# [122 rows x 5 columns]
